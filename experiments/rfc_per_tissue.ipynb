# %% [markdown]
# # Run RFC per Tissue

# %%
import os
import torch
import pickle
import time
import pandas as pd
import torch.nn.functional as F
from omegaconf import OmegaConf, DictConfig
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    roc_auc_score, mean_squared_error, accuracy_score,
    precision_score, recall_score, f1_score
)

from utils.knowledge_db import CODON_MAP_DNA, TISSUES, TOKENS
from utils.utils import set_project_path, set_log_file, check_config
from data_handling.data_loader import RNADataset

TISSUES_DICT = {k: v for k, v in enumerate(TISSUES)}

# %%
from sklearn.neural_network import MLPClassifier

# Random Forest results
results_rf = []

# MLP results
results_mlp = []

for tissue_id in range(29):
    dev_config["tissue_id"] = tissue_id

    train_dataset = RNADataset(dev_config, tissue_id)
    val_dataset = RNADataset(dev_config, tissue_id, test=True)

    x_train = train_dataset.freqs
    y_train = train_dataset.targets_bin
    x_val = val_dataset.freqs
    y_val = val_dataset.targets_bin

    # --- Random Forest ---
    rf_model = RandomForestClassifier(random_state=42)
    start_time = time.time()
    rf_model.fit(x_train, y_train)
    rf_time = time.time() - start_time

    y_train_rf_proba = rf_model.predict_proba(x_train)[:, 1]
    y_train_rf_pred = (y_train_rf_proba >= 0.5).astype(int)
    y_val_rf_proba = rf_model.predict_proba(x_val)[:, 1]
    y_val_rf_pred = (y_val_rf_proba >= 0.5).astype(int)

    results_rf.append({
        "Tissue": TISSUES_DICT[tissue_id],
        "Train AUC": roc_auc_score(y_train, y_train_rf_proba),
        "Train F1": f1_score(y_train, y_train_rf_pred, zero_division=0),
        "Train Accuracy": accuracy_score(y_train, y_train_rf_pred),
        "Train Precision": precision_score(y_train, y_train_rf_pred, zero_division=0),
        "Train Recall": recall_score(y_train, y_train_rf_pred, zero_division=0),
        "Test AUC": roc_auc_score(y_val, y_val_rf_proba),
        "Test F1": f1_score(y_val, y_val_rf_pred, zero_division=0),
        "Test Accuracy": accuracy_score(y_val, y_val_rf_pred),
        "Test Precision": precision_score(y_val, y_val_rf_pred, zero_division=0),
        "Test Recall": recall_score(y_val, y_val_rf_pred, zero_division=0),
        "Train Time (s)": rf_time
    })

    # --- MLP ---
    mlp_model = MLPClassifier(hidden_layer_sizes=(512), activation='relu', max_iter=500, random_state=42)
    start_time = time.time()
    mlp_model.fit(x_train, y_train)
    mlp_time = time.time() - start_time

    y_train_mlp_proba = mlp_model.predict_proba(x_train)[:, 1]
    y_train_mlp_pred = (y_train_mlp_proba >= 0.5).astype(int)
    y_val_mlp_proba = mlp_model.predict_proba(x_val)[:, 1]
    y_val_mlp_pred = (y_val_mlp_proba >= 0.5).astype(int)

    results_mlp.append({
        "Tissue": TISSUES_DICT[tissue_id],
        "Train AUC": roc_auc_score(y_train, y_train_mlp_proba),
        "Train F1": f1_score(y_train, y_train_mlp_pred, zero_division=0),
        "Train Accuracy": accuracy_score(y_train, y_train_mlp_pred),
        "Train Precision": precision_score(y_train, y_train_mlp_pred, zero_division=0),
        "Train Recall": recall_score(y_train, y_train_mlp_pred, zero_division=0),
        "Test AUC": roc_auc_score(y_val, y_val_mlp_proba),
        "Test F1": f1_score(y_val, y_val_mlp_pred, zero_division=0),
        "Test Accuracy": accuracy_score(y_val, y_val_mlp_pred),
        "Test Precision": precision_score(y_val, y_val_mlp_pred, zero_division=0),
        "Test Recall": recall_score(y_val, y_val_mlp_pred, zero_division=0),
        "Train Time (s)": mlp_time
    })

# Convert results to DataFrames
df_results_rf = pd.DataFrame(results_rf)
df_results_mlp = pd.DataFrame(results_mlp)
# Out:
# 2025-06-20 13:24:25,891 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:24:41,744 - root - WARNING - Only keeping data for TISSUE Adrenal
# 2025-06-20 13:24:41,745 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:24:42,374 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:24:45,650 - root - WARNING - Only keeping data for TISSUE Adrenal
# 2025-06-20 13:24:45,652 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:24:45,793 - root - INFO - Adding validation dataset with 72 samples to train
# 2025-06-20 13:24:45,795 - root - INFO - Train dataset with 330 samples loaded
# 2025-06-20 13:24:45,796 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:24:45,800 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 0          0              145
#            1              185
# Name: targets, dtype: int64
# 2025-06-20 13:24:45,802 - root - INFO -   Seq len distribution:
# (array([36, 61, 46, 59, 40, 31, 19, 14, 17,  7]), array([ 496. , 1343.5, 2191. , 3038.5, 3886. , 4733.5, 5581. , 6428.5,
#        7276. , 8123.5, 8971. ]))
# 2025-06-20 13:24:45,803 - root - WARNING - TRAIN DATASET HAS ONLY 330 SAMPLES
# 2025-06-20 13:24:46,145 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:24:49,565 - root - WARNING - Only keeping data for TISSUE Adrenal
# 2025-06-20 13:24:49,566 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:24:49,698 - root - INFO - Test dataset with 47 samples loaded
# 2025-06-20 13:24:49,704 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:24:49,707 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 0          0              24
#            1              23
# Name: targets, dtype: int64
# 2025-06-20 13:24:49,709 - root - INFO -   Seq len distribution:
# (array([ 5, 10,  8,  5,  6,  2,  5,  4,  1,  1]), array([ 730. , 1507.5, 2285. , 3062.5, 3840. , 4617.5, 5395. , 6172.5,
#        6950. , 7727.5, 8505. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:24:52,808 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:25:08,606 - root - WARNING - Only keeping data for TISSUE Appendices
# 2025-06-20 13:25:08,607 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:25:09,233 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:25:12,701 - root - WARNING - Only keeping data for TISSUE Appendices
# 2025-06-20 13:25:12,703 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:25:12,851 - root - INFO - Adding validation dataset with 120 samples to train
# 2025-06-20 13:25:12,852 - root - INFO - Train dataset with 707 samples loaded
# 2025-06-20 13:25:12,854 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:25:12,857 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 1          0              490
#            1              217
# Name: targets, dtype: int64
# 2025-06-20 13:25:12,860 - root - INFO -   Seq len distribution:
# (array([ 84, 134, 150, 111,  81,  55,  37,  22,  17,  16]), array([ 394. , 1240.7, 2087.4, 2934.1, 3780.8, 4627.5, 5474.2, 6320.9,
#        7167.6, 8014.3, 8861. ]))
# 2025-06-20 13:25:12,861 - root - WARNING - TRAIN DATASET HAS ONLY 707 SAMPLES
# 2025-06-20 13:25:13,492 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:25:16,881 - root - WARNING - Only keeping data for TISSUE Appendices
# 2025-06-20 13:25:16,883 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:25:17,014 - root - INFO - Test dataset with 132 samples loaded
# 2025-06-20 13:25:17,022 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:25:17,026 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 1          0              89
#            1              43
# Name: targets, dtype: int64
# 2025-06-20 13:25:17,027 - root - INFO -   Seq len distribution:
# (array([27, 26, 18, 17, 15, 10,  9,  6,  1,  3]), array([ 478. , 1295.4, 2112.8, 2930.2, 3747.6, 4565. , 5382.4, 6199.8,
#        7017.2, 7834.6, 8652. ]))
# 2025-06-20 13:25:22,028 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:25:38,156 - root - WARNING - Only keeping data for TISSUE Brain
# 2025-06-20 13:25:38,158 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:25:38,761 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:25:41,940 - root - WARNING - Only keeping data for TISSUE Brain
# 2025-06-20 13:25:41,942 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:25:42,081 - root - INFO - Adding validation dataset with 166 samples to train
# 2025-06-20 13:25:42,082 - root - INFO - Train dataset with 863 samples loaded
# 2025-06-20 13:25:42,084 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:25:42,088 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 2          0              243
#            1              620
# Name: targets, dtype: int64
# 2025-06-20 13:25:42,090 - root - INFO -   Seq len distribution:
# (array([ 84, 143, 161, 146, 109,  88,  45,  41,  22,  24]), array([ 425. , 1279.9, 2134.8, 2989.7, 3844.6, 4699.5, 5554.4, 6409.3,
#        7264.2, 8119.1, 8974. ]))
# 2025-06-20 13:25:42,091 - root - WARNING - TRAIN DATASET HAS ONLY 863 SAMPLES
# 2025-06-20 13:25:42,904 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:25:46,023 - root - WARNING - Only keeping data for TISSUE Brain
# 2025-06-20 13:25:46,025 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:25:46,144 - root - INFO - Test dataset with 119 samples loaded
# 2025-06-20 13:25:46,153 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:25:46,157 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 2          0              38
#            1              81
# Name: targets, dtype: int64
# 2025-06-20 13:25:46,158 - root - INFO -   Seq len distribution:
# (array([18, 24, 25, 13, 10, 12,  7,  5,  1,  4]), array([ 513. , 1326.8, 2140.6, 2954.4, 3768.2, 4582. , 5395.8, 6209.6,
#        7023.4, 7837.2, 8651. ]))
# 2025-06-20 13:25:52,573 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:26:07,863 - root - WARNING - Only keeping data for TISSUE Colon
# 2025-06-20 13:26:07,865 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:26:08,440 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:26:11,471 - root - WARNING - Only keeping data for TISSUE Colon
# 2025-06-20 13:26:11,473 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:26:11,609 - root - INFO - Adding validation dataset with 84 samples to train
# 2025-06-20 13:26:11,611 - root - INFO - Train dataset with 475 samples loaded
# 2025-06-20 13:26:11,612 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:26:11,616 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 3          0              253
#            1              222
# Name: targets, dtype: int64
# 2025-06-20 13:26:11,618 - root - INFO -   Seq len distribution:
# (array([ 50,  88, 100,  72,  57,  34,  32,  20,  11,  11]), array([ 340. , 1178.1, 2016.2, 2854.3, 3692.4, 4530.5, 5368.6, 6206.7,
#        7044.8, 7882.9, 8721. ]))
# 2025-06-20 13:26:11,619 - root - WARNING - TRAIN DATASET HAS ONLY 475 SAMPLES
# 2025-06-20 13:26:12,031 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:26:15,128 - root - WARNING - Only keeping data for TISSUE Colon
# 2025-06-20 13:26:15,130 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:26:15,453 - root - INFO - Test dataset with 85 samples loaded
# 2025-06-20 13:26:15,461 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:26:15,464 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 3          0              44
#            1              41
# Name: targets, dtype: int64
# 2025-06-20 13:26:15,466 - root - INFO -   Seq len distribution:
# (array([18, 18, 14, 11,  9,  5,  2,  2,  3,  3]), array([ 582. , 1403.4, 2224.8, 3046.2, 3867.6, 4689. , 5510.4, 6331.8,
#        7153.2, 7974.6, 8796. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:26:19,854 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:26:34,506 - root - WARNING - Only keeping data for TISSUE Duodenum
# 2025-06-20 13:26:34,507 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:26:35,083 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:26:38,077 - root - WARNING - Only keeping data for TISSUE Duodenum
# 2025-06-20 13:26:38,079 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:26:38,410 - root - INFO - Adding validation dataset with 59 samples to train
# 2025-06-20 13:26:38,411 - root - INFO - Train dataset with 357 samples loaded
# 2025-06-20 13:26:38,412 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:26:38,416 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 4          0              189
#            1              168
# Name: targets, dtype: int64
# 2025-06-20 13:26:38,418 - root - INFO -   Seq len distribution:
# (array([32, 56, 77, 46, 43, 29, 31, 19, 13, 11]), array([ 408. , 1186.7, 1965.4, 2744.1, 3522.8, 4301.5, 5080.2, 5858.9,
#        6637.6, 7416.3, 8195. ]))
# 2025-06-20 13:26:38,419 - root - WARNING - TRAIN DATASET HAS ONLY 357 SAMPLES
# 2025-06-20 13:26:38,745 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:26:41,726 - root - WARNING - Only keeping data for TISSUE Duodenum
# 2025-06-20 13:26:41,728 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:26:41,846 - root - INFO - Test dataset with 59 samples loaded
# 2025-06-20 13:26:41,853 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:26:41,856 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 4          0              34
#            1              25
# Name: targets, dtype: int64
# 2025-06-20 13:26:41,857 - root - INFO -   Seq len distribution:
# (array([ 9, 12,  7, 12,  5,  4,  7,  2,  0,  1]), array([ 390. , 1216.1, 2042.2, 2868.3, 3694.4, 4520.5, 5346.6, 6172.7,
#        6998.8, 7824.9, 8651. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:26:45,016 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:26:59,873 - root - WARNING - Only keeping data for TISSUE Uterus
# 2025-06-20 13:26:59,875 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:27:00,450 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:27:03,627 - root - WARNING - Only keeping data for TISSUE Uterus
# 2025-06-20 13:27:03,629 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:27:03,757 - root - INFO - Adding validation dataset with 52 samples to train
# 2025-06-20 13:27:03,758 - root - INFO - Train dataset with 269 samples loaded
# 2025-06-20 13:27:03,760 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:27:03,762 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 5          0              111
#            1              158
# Name: targets, dtype: int64
# 2025-06-20 13:27:03,765 - root - INFO -   Seq len distribution:
# (array([27, 49, 52, 37, 39, 16, 15, 12, 13,  9]), array([ 487. , 1256.8, 2026.6, 2796.4, 3566.2, 4336. , 5105.8, 5875.6,
#        6645.4, 7415.2, 8185. ]))
# 2025-06-20 13:27:03,766 - root - WARNING - TRAIN DATASET HAS ONLY 269 SAMPLES
# 2025-06-20 13:27:04,008 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:27:07,130 - root - WARNING - Only keeping data for TISSUE Uterus
# 2025-06-20 13:27:07,132 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:27:07,252 - root - INFO - Test dataset with 53 samples loaded
# 2025-06-20 13:27:07,258 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:27:07,261 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 5          0              24
#            1              29
# Name: targets, dtype: int64
# 2025-06-20 13:27:07,262 - root - INFO -   Seq len distribution:
# (array([ 4, 17,  9,  2,  5,  7,  4,  2,  0,  3]), array([ 390. , 1211.3, 2032.6, 2853.9, 3675.2, 4496.5, 5317.8, 6139.1,
#        6960.4, 7781.7, 8603. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:27:09,975 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:27:24,377 - root - WARNING - Only keeping data for TISSUE Esophagus
# 2025-06-20 13:27:24,378 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:27:25,300 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:27:28,275 - root - WARNING - Only keeping data for TISSUE Esophagus
# 2025-06-20 13:27:28,276 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:27:28,409 - root - INFO - Adding validation dataset with 96 samples to train
# 2025-06-20 13:27:28,410 - root - INFO - Train dataset with 498 samples loaded
# 2025-06-20 13:27:28,411 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:27:28,415 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 6          0              316
#            1              182
# Name: targets, dtype: int64
# 2025-06-20 13:27:28,417 - root - INFO -   Seq len distribution:
# (array([52, 83, 89, 88, 63, 42, 39, 15, 15, 12]), array([ 408. , 1255.6, 2103.2, 2950.8, 3798.4, 4646. , 5493.6, 6341.2,
#        7188.8, 8036.4, 8884. ]))
# 2025-06-20 13:27:28,418 - root - WARNING - TRAIN DATASET HAS ONLY 498 SAMPLES
# 2025-06-20 13:27:28,872 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:27:31,775 - root - WARNING - Only keeping data for TISSUE Esophagus
# 2025-06-20 13:27:31,777 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:27:31,898 - root - INFO - Test dataset with 90 samples loaded
# 2025-06-20 13:27:31,905 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:27:31,907 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 6          0              59
#            1              31
# Name: targets, dtype: int64
# 2025-06-20 13:27:31,909 - root - INFO -   Seq len distribution:
# (array([ 9, 13, 25, 14,  8,  4,  5,  7,  2,  3]), array([ 534. , 1315.6, 2097.2, 2878.8, 3660.4, 4442. , 5223.6, 6005.2,
#        6786.8, 7568.4, 8350. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:27:36,392 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:27:50,617 - root - WARNING - Only keeping data for TISSUE Fallopiantube
# 2025-06-20 13:27:50,619 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:27:51,194 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:27:54,288 - root - WARNING - Only keeping data for TISSUE Fallopiantube
# 2025-06-20 13:27:54,289 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:27:54,615 - root - INFO - Adding validation dataset with 75 samples to train
# 2025-06-20 13:27:54,623 - root - INFO - Train dataset with 430 samples loaded
# 2025-06-20 13:27:54,624 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:27:54,627 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 7          0              171
#            1              259
# Name: targets, dtype: int64
# 2025-06-20 13:27:54,629 - root - INFO -   Seq len distribution:
# (array([44, 77, 83, 66, 60, 24, 31, 20, 10, 15]), array([ 408., 1216., 2024., 2832., 3640., 4448., 5256., 6064., 6872.,
#        7680., 8488.]))
# 2025-06-20 13:27:54,629 - root - WARNING - TRAIN DATASET HAS ONLY 430 SAMPLES
# 2025-06-20 13:27:55,019 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:27:58,211 - root - WARNING - Only keeping data for TISSUE Fallopiantube
# 2025-06-20 13:27:58,213 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:27:58,342 - root - INFO - Test dataset with 89 samples loaded
# 2025-06-20 13:27:58,349 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:27:58,352 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 7          0              27
#            1              62
# Name: targets, dtype: int64
# 2025-06-20 13:27:58,354 - root - INFO -   Seq len distribution:
# (array([12, 21, 13, 13, 16,  3,  2,  4,  3,  2]), array([ 592. , 1383.3, 2174.6, 2965.9, 3757.2, 4548.5, 5339.8, 6131.1,
#        6922.4, 7713.7, 8505. ]))
# 2025-06-20 13:28:02,177 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:28:17,798 - root - WARNING - Only keeping data for TISSUE Fat
# 2025-06-20 13:28:17,799 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:28:18,472 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:28:21,725 - root - WARNING - Only keeping data for TISSUE Fat
# 2025-06-20 13:28:21,727 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:28:22,081 - root - INFO - Adding validation dataset with 123 samples to train
# 2025-06-20 13:28:22,083 - root - INFO - Train dataset with 788 samples loaded
# 2025-06-20 13:28:22,085 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:28:22,088 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 8          0              575
#            1              213
# Name: targets, dtype: int64
# 2025-06-20 13:28:22,091 - root - INFO -   Seq len distribution:
# (array([ 58, 127, 132, 146, 120,  68,  47,  39,  25,  26]), array([ 317. , 1183.5, 2050. , 2916.5, 3783. , 4649.5, 5516. , 6382.5,
#        7249. , 8115.5, 8982. ]))
# 2025-06-20 13:28:22,092 - root - WARNING - TRAIN DATASET HAS ONLY 788 SAMPLES
# 2025-06-20 13:28:22,875 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:28:26,071 - root - WARNING - Only keeping data for TISSUE Fat
# 2025-06-20 13:28:26,072 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:28:26,202 - root - INFO - Test dataset with 146 samples loaded
# 2025-06-20 13:28:26,210 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:28:26,213 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 8          0              108
#            1               38
# Name: targets, dtype: int64
# 2025-06-20 13:28:26,215 - root - INFO -   Seq len distribution:
# (array([15, 24, 30, 21, 11, 16, 12,  6,  3,  8]), array([ 452. , 1274.9, 2097.8, 2920.7, 3743.6, 4566.5, 5389.4, 6212.3,
#        7035.2, 7858.1, 8681. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:28:33,050 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:28:48,637 - root - WARNING - Only keeping data for TISSUE Gallbladder
# 2025-06-20 13:28:48,638 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:28:49,265 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:28:52,699 - root - WARNING - Only keeping data for TISSUE Gallbladder
# 2025-06-20 13:28:52,700 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:28:52,844 - root - INFO - Adding validation dataset with 54 samples to train
# 2025-06-20 13:28:52,845 - root - INFO - Train dataset with 355 samples loaded
# 2025-06-20 13:28:52,846 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:28:52,849 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 9          0              205
#            1              150
# Name: targets, dtype: int64
# 2025-06-20 13:28:52,851 - root - INFO -   Seq len distribution:
# (array([45, 79, 71, 47, 43, 32, 12, 11,  9,  6]), array([ 413. , 1270.8, 2128.6, 2986.4, 3844.2, 4702. , 5559.8, 6417.6,
#        7275.4, 8133.2, 8991. ]))
# 2025-06-20 13:28:52,851 - root - WARNING - TRAIN DATASET HAS ONLY 355 SAMPLES
# 2025-06-20 13:28:53,169 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:28:56,344 - root - WARNING - Only keeping data for TISSUE Gallbladder
# 2025-06-20 13:28:56,345 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:28:56,688 - root - INFO - Test dataset with 69 samples loaded
# 2025-06-20 13:28:56,696 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:28:56,699 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 9          0              44
#            1              25
# Name: targets, dtype: int64
# 2025-06-20 13:28:56,700 - root - INFO -   Seq len distribution:
# (array([ 8, 16, 10,  6,  8, 11,  4,  3,  0,  3]), array([ 583. , 1404.3, 2225.6, 3046.9, 3868.2, 4689.5, 5510.8, 6332.1,
#        7153.4, 7974.7, 8796. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:28:59,879 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:29:17,980 - root - WARNING - Only keeping data for TISSUE Heart
# 2025-06-20 13:29:17,982 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:29:18,688 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:29:22,707 - root - WARNING - Only keeping data for TISSUE Heart
# 2025-06-20 13:29:22,710 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:29:22,863 - root - INFO - Adding validation dataset with 120 samples to train
# 2025-06-20 13:29:22,864 - root - INFO - Train dataset with 749 samples loaded
# 2025-06-20 13:29:22,867 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:29:22,870 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 10         0              455
#            1              294
# Name: targets, dtype: int64
# 2025-06-20 13:29:22,874 - root - INFO -   Seq len distribution:
# (array([ 81, 160, 145,  85,  86,  58,  53,  34,  23,  24]), array([ 421., 1276., 2131., 2986., 3841., 4696., 5551., 6406., 7261.,
#        8116., 8971.]))
# 2025-06-20 13:29:22,875 - root - WARNING - TRAIN DATASET HAS ONLY 749 SAMPLES
# 2025-06-20 13:29:23,621 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:29:27,531 - root - WARNING - Only keeping data for TISSUE Heart
# 2025-06-20 13:29:27,533 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:29:27,672 - root - INFO - Test dataset with 123 samples loaded
# 2025-06-20 13:29:27,681 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:29:27,684 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 10         0              72
#            1              51
# Name: targets, dtype: int64
# 2025-06-20 13:29:27,685 - root - INFO -   Seq len distribution:
# (array([11, 21, 36, 20, 14,  7,  3,  3,  6,  2]), array([ 407. , 1249.4, 2091.8, 2934.2, 3776.6, 4619. , 5461.4, 6303.8,
#        7146.2, 7988.6, 8831. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:29:34,157 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:29:52,022 - root - WARNING - Only keeping data for TISSUE Kidney
# 2025-06-20 13:29:52,023 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:29:52,660 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:29:56,445 - root - WARNING - Only keeping data for TISSUE Kidney
# 2025-06-20 13:29:56,447 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:29:56,596 - root - INFO - Adding validation dataset with 126 samples to train
# 2025-06-20 13:29:56,598 - root - INFO - Train dataset with 678 samples loaded
# 2025-06-20 13:29:56,600 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:29:56,603 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 11         0              325
#            1              353
# Name: targets, dtype: int64
# 2025-06-20 13:29:56,606 - root - INFO -   Seq len distribution:
# (array([100, 132, 111, 109,  76,  48,  38,  25,  21,  18]), array([ 394. , 1248.4, 2102.8, 2957.2, 3811.6, 4666. , 5520.4, 6374.8,
#        7229.2, 8083.6, 8938. ]))
# 2025-06-20 13:29:56,606 - root - WARNING - TRAIN DATASET HAS ONLY 678 SAMPLES
# 2025-06-20 13:29:57,226 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:30:00,732 - root - WARNING - Only keeping data for TISSUE Kidney
# 2025-06-20 13:30:00,733 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:30:00,871 - root - INFO - Test dataset with 128 samples loaded
# 2025-06-20 13:30:00,880 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:30:00,883 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 11         0              66
#            1              62
# Name: targets, dtype: int64
# 2025-06-20 13:30:00,884 - root - INFO -   Seq len distribution:
# (array([21, 29, 27, 10,  8, 12, 10,  7,  1,  3]), array([ 355. , 1182.8, 2010.6, 2838.4, 3666.2, 4494. , 5321.8, 6149.6,
#        6977.4, 7805.2, 8633. ]))
# 2025-06-20 13:30:06,452 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:30:24,349 - root - WARNING - Only keeping data for TISSUE Liver
# 2025-06-20 13:30:24,350 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:30:25,070 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:30:28,606 - root - WARNING - Only keeping data for TISSUE Liver
# 2025-06-20 13:30:28,608 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:30:28,765 - root - INFO - Adding validation dataset with 103 samples to train
# 2025-06-20 13:30:28,766 - root - INFO - Train dataset with 602 samples loaded
# 2025-06-20 13:30:28,768 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:30:28,771 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 12         0              358
#            1              244
# Name: targets, dtype: int64
# 2025-06-20 13:30:28,774 - root - INFO -   Seq len distribution:
# (array([ 57, 135, 112,  89,  71,  49,  33,  23,  21,  12]), array([ 455. , 1305.9, 2156.8, 3007.7, 3858.6, 4709.5, 5560.4, 6411.3,
#        7262.2, 8113.1, 8964. ]))
# 2025-06-20 13:30:28,775 - root - WARNING - TRAIN DATASET HAS ONLY 602 SAMPLES
# 2025-06-20 13:30:29,342 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:30:32,969 - root - WARNING - Only keeping data for TISSUE Liver
# 2025-06-20 13:30:32,971 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:30:33,111 - root - INFO - Test dataset with 118 samples loaded
# 2025-06-20 13:30:33,119 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:30:33,122 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 12         0              78
#            1              40
# Name: targets, dtype: int64
# 2025-06-20 13:30:33,124 - root - INFO -   Seq len distribution:
# (array([19, 28, 24, 17,  8,  9,  4,  4,  4,  1]), array([ 562., 1405., 2248., 3091., 3934., 4777., 5620., 6463., 7306.,
#        8149., 8992.]))
# 2025-06-20 13:30:34,515 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:30:50,601 - root - WARNING - Only keeping data for TISSUE Lung
# 2025-06-20 13:30:50,603 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:30:51,255 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:30:54,741 - root - WARNING - Only keeping data for TISSUE Lung
# 2025-06-20 13:30:54,743 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:30:54,898 - root - INFO - Adding validation dataset with 167 samples to train
# 2025-06-20 13:30:54,900 - root - INFO - Train dataset with 980 samples loaded
# 2025-06-20 13:30:54,901 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:30:54,905 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 13         0              351
#            1              629
# Name: targets, dtype: int64
# 2025-06-20 13:30:54,908 - root - INFO -   Seq len distribution:
# (array([ 86, 195, 195, 145, 108,  98,  61,  41,  20,  31]), array([ 317. , 1183.3, 2049.6, 2915.9, 3782.2, 4648.5, 5514.8, 6381.1,
#        7247.4, 8113.7, 8980. ]))
# 2025-06-20 13:30:54,909 - root - WARNING - TRAIN DATASET HAS ONLY 980 SAMPLES
# 2025-06-20 13:30:55,815 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:30:59,172 - root - WARNING - Only keeping data for TISSUE Lung
# 2025-06-20 13:30:59,174 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:30:59,301 - root - INFO - Test dataset with 158 samples loaded
# 2025-06-20 13:30:59,311 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:30:59,314 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 13         0               55
#            1              103
# Name: targets, dtype: int64
# 2025-06-20 13:30:59,315 - root - INFO -   Seq len distribution:
# (array([19, 33, 29, 13, 16, 13, 13,  8,  7,  7]), array([ 662. , 1443.7, 2225.4, 3007.1, 3788.8, 4570.5, 5352.2, 6133.9,
#        6915.6, 7697.3, 8479. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:31:07,567 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:31:23,031 - root - WARNING - Only keeping data for TISSUE Lymphnode
# 2025-06-20 13:31:23,033 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:31:23,608 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:31:26,758 - root - WARNING - Only keeping data for TISSUE Lymphnode
# 2025-06-20 13:31:26,759 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:31:26,895 - root - INFO - Adding validation dataset with 69 samples to train
# 2025-06-20 13:31:26,896 - root - INFO - Train dataset with 419 samples loaded
# 2025-06-20 13:31:26,898 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:31:26,901 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 14         0              199
#            1              220
# Name: targets, dtype: int64
# 2025-06-20 13:31:26,903 - root - INFO -   Seq len distribution:
# (array([40, 90, 85, 73, 41, 27, 26, 14, 12, 11]), array([ 303. , 1170.1, 2037.2, 2904.3, 3771.4, 4638.5, 5505.6, 6372.7,
#        7239.8, 8106.9, 8974. ]))
# 2025-06-20 13:31:26,904 - root - WARNING - TRAIN DATASET HAS ONLY 419 SAMPLES
# 2025-06-20 13:31:27,275 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:31:30,392 - root - WARNING - Only keeping data for TISSUE Lymphnode
# 2025-06-20 13:31:30,394 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:31:30,515 - root - INFO - Test dataset with 60 samples loaded
# 2025-06-20 13:31:30,523 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:31:30,526 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 14         0              25
#            1              35
# Name: targets, dtype: int64
# 2025-06-20 13:31:30,527 - root - INFO -   Seq len distribution:
# (array([11,  9, 10,  9,  2, 10,  3,  2,  0,  4]), array([ 563., 1346., 2129., 2912., 3695., 4478., 5261., 6044., 6827.,
#        7610., 8393.]))
# 2025-06-20 13:31:31,182 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:31:45,300 - root - WARNING - Only keeping data for TISSUE Ovary
# 2025-06-20 13:31:45,302 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:31:45,904 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:31:49,046 - root - WARNING - Only keeping data for TISSUE Ovary
# 2025-06-20 13:31:49,048 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:31:49,186 - root - INFO - Adding validation dataset with 148 samples to train
# 2025-06-20 13:31:49,187 - root - INFO - Train dataset with 803 samples loaded
# 2025-06-20 13:31:49,189 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:31:49,192 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 15         0              432
#            1              371
# Name: targets, dtype: int64
# 2025-06-20 13:31:49,195 - root - INFO -   Seq len distribution:
# (array([119, 162, 149, 114,  99,  53,  50,  23,  19,  15]), array([ 401. , 1257.3, 2113.6, 2969.9, 3826.2, 4682.5, 5538.8, 6395.1,
#        7251.4, 8107.7, 8964. ]))
# 2025-06-20 13:31:49,196 - root - WARNING - TRAIN DATASET HAS ONLY 803 SAMPLES
# 2025-06-20 13:31:49,875 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:31:52,956 - root - WARNING - Only keeping data for TISSUE Ovary
# 2025-06-20 13:31:52,958 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:31:53,078 - root - INFO - Test dataset with 131 samples loaded
# 2025-06-20 13:31:53,086 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:31:53,089 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 15         0              63
#            1              68
# Name: targets, dtype: int64
# 2025-06-20 13:31:53,090 - root - INFO -   Seq len distribution:
# (array([12, 26, 36, 21, 14, 11,  7,  3,  0,  1]), array([ 355. , 1187.9, 2020.8, 2853.7, 3686.6, 4519.5, 5352.4, 6185.3,
#        7018.2, 7851.1, 8684. ]))
# 2025-06-20 13:31:54,240 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:32:08,202 - root - WARNING - Only keeping data for TISSUE Pancreas
# 2025-06-20 13:32:08,204 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:32:09,155 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:32:12,142 - root - WARNING - Only keeping data for TISSUE Pancreas
# 2025-06-20 13:32:12,144 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:32:12,485 - root - INFO - Adding validation dataset with 186 samples to train
# 2025-06-20 13:32:12,486 - root - INFO - Train dataset with 982 samples loaded
# 2025-06-20 13:32:12,488 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:32:12,492 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 16         0              579
#            1              403
# Name: targets, dtype: int64
# 2025-06-20 13:32:12,495 - root - INFO -   Seq len distribution:
# (array([110, 185, 184, 169, 115,  77,  52,  34,  30,  26]), array([ 410. , 1266.6, 2123.2, 2979.8, 3836.4, 4693. , 5549.6, 6406.2,
#        7262.8, 8119.4, 8976. ]))
# 2025-06-20 13:32:12,495 - root - WARNING - TRAIN DATASET HAS ONLY 982 SAMPLES
# 2025-06-20 13:32:13,390 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:32:16,301 - root - WARNING - Only keeping data for TISSUE Pancreas
# 2025-06-20 13:32:16,303 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:32:16,423 - root - INFO - Test dataset with 168 samples loaded
# 2025-06-20 13:32:16,433 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:32:16,435 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 16         0              97
#            1              71
# Name: targets, dtype: int64
# 2025-06-20 13:32:16,437 - root - INFO -   Seq len distribution:
# (array([19, 29, 37, 20, 19, 14, 10,  6, 10,  4]), array([ 355. , 1179.8, 2004.6, 2829.4, 3654.2, 4479. , 5303.8, 6128.6,
#        6953.4, 7778.2, 8603. ]))
# 2025-06-20 13:32:23,202 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:32:37,419 - root - WARNING - Only keeping data for TISSUE Placenta
# 2025-06-20 13:32:37,421 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:32:38,026 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:32:41,166 - root - WARNING - Only keeping data for TISSUE Placenta
# 2025-06-20 13:32:41,168 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:32:41,303 - root - INFO - Adding validation dataset with 87 samples to train
# 2025-06-20 13:32:41,305 - root - INFO - Train dataset with 468 samples loaded
# 2025-06-20 13:32:41,307 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:32:41,310 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 17         0              217
#            1              251
# Name: targets, dtype: int64
# 2025-06-20 13:32:41,312 - root - INFO -   Seq len distribution:
# (array([ 54, 100,  79,  72,  55,  42,  22,  13,  22,   9]), array([ 486. , 1335.4, 2184.8, 3034.2, 3883.6, 4733. , 5582.4, 6431.8,
#        7281.2, 8130.6, 8980. ]))
# 2025-06-20 13:32:41,313 - root - WARNING - TRAIN DATASET HAS ONLY 468 SAMPLES
# 2025-06-20 13:32:41,741 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:32:44,807 - root - WARNING - Only keeping data for TISSUE Placenta
# 2025-06-20 13:32:44,808 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:32:44,929 - root - INFO - Test dataset with 82 samples loaded
# 2025-06-20 13:32:44,937 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:32:44,940 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 17         0              30
#            1              52
# Name: targets, dtype: int64
# 2025-06-20 13:32:44,941 - root - INFO -   Seq len distribution:
# (array([13, 14, 14,  8, 16,  6,  2,  2,  4,  3]), array([ 708. , 1443.8, 2179.6, 2915.4, 3651.2, 4387. , 5122.8, 5858.6,
#        6594.4, 7330.2, 8066. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:32:49,226 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:33:04,349 - root - WARNING - Only keeping data for TISSUE Prostate
# 2025-06-20 13:33:04,350 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:33:04,933 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:33:08,242 - root - WARNING - Only keeping data for TISSUE Prostate
# 2025-06-20 13:33:08,244 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:33:08,378 - root - INFO - Adding validation dataset with 86 samples to train
# 2025-06-20 13:33:08,380 - root - INFO - Train dataset with 467 samples loaded
# 2025-06-20 13:33:08,381 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:33:08,385 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 18         0              243
#            1              224
# Name: targets, dtype: int64
# 2025-06-20 13:33:08,387 - root - INFO -   Seq len distribution:
# (array([44, 97, 88, 66, 55, 38, 36, 21, 11, 11]), array([ 303. , 1148.5, 1994. , 2839.5, 3685. , 4530.5, 5376. , 6221.5,
#        7067. , 7912.5, 8758. ]))
# 2025-06-20 13:33:08,388 - root - WARNING - TRAIN DATASET HAS ONLY 467 SAMPLES
# 2025-06-20 13:33:08,802 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:33:12,024 - root - WARNING - Only keeping data for TISSUE Prostate
# 2025-06-20 13:33:12,026 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:33:12,147 - root - INFO - Test dataset with 82 samples loaded
# 2025-06-20 13:33:12,155 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:33:12,158 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 18         0              51
#            1              31
# Name: targets, dtype: int64
# 2025-06-20 13:33:12,159 - root - INFO -   Seq len distribution:
# (array([19, 15, 14, 11,  5,  3,  6,  3,  4,  2]), array([ 503. , 1299.7, 2096.4, 2893.1, 3689.8, 4486.5, 5283.2, 6079.9,
#        6876.6, 7673.3, 8470. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:33:16,469 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:33:31,549 - root - WARNING - Only keeping data for TISSUE Rectum
# 2025-06-20 13:33:31,550 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:33:32,152 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:33:35,341 - root - WARNING - Only keeping data for TISSUE Rectum
# 2025-06-20 13:33:35,343 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:33:35,671 - root - INFO - Adding validation dataset with 68 samples to train
# 2025-06-20 13:33:35,672 - root - INFO - Train dataset with 340 samples loaded
# 2025-06-20 13:33:35,674 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:33:35,676 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 19         0              139
#            1              201
# Name: targets, dtype: int64
# 2025-06-20 13:33:35,678 - root - INFO -   Seq len distribution:
# (array([42, 84, 62, 48, 35, 18, 27,  8,  8,  8]), array([ 520. , 1365.4, 2210.8, 3056.2, 3901.6, 4747. , 5592.4, 6437.8,
#        7283.2, 8128.6, 8974. ]))
# 2025-06-20 13:33:35,679 - root - WARNING - TRAIN DATASET HAS ONLY 340 SAMPLES
# 2025-06-20 13:33:35,979 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:33:38,962 - root - WARNING - Only keeping data for TISSUE Rectum
# 2025-06-20 13:33:38,964 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:33:39,084 - root - INFO - Test dataset with 54 samples loaded
# 2025-06-20 13:33:39,090 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:33:39,093 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 19         0              25
#            1              29
# Name: targets, dtype: int64
# 2025-06-20 13:33:39,095 - root - INFO -   Seq len distribution:
# (array([ 9,  8, 17,  6,  3,  0,  7,  0,  2,  2]), array([ 560. , 1388.6, 2217.2, 3045.8, 3874.4, 4703. , 5531.6, 6360.2,
#        7188.8, 8017.4, 8846. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:33:42,174 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:33:57,108 - root - WARNING - Only keeping data for TISSUE Salivarygland
# 2025-06-20 13:33:57,109 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:33:57,686 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:34:00,671 - root - WARNING - Only keeping data for TISSUE Salivarygland
# 2025-06-20 13:34:00,673 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:34:01,017 - root - INFO - Adding validation dataset with 91 samples to train
# 2025-06-20 13:34:01,018 - root - INFO - Train dataset with 532 samples loaded
# 2025-06-20 13:34:01,020 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:34:01,023 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 20         0              276
#            1              256
# Name: targets, dtype: int64
# 2025-06-20 13:34:01,025 - root - INFO -   Seq len distribution:
# (array([ 64, 106,  88,  60,  72,  52,  33,  29,  17,  11]), array([ 375. , 1229.7, 2084.4, 2939.1, 3793.8, 4648.5, 5503.2, 6357.9,
#        7212.6, 8067.3, 8922. ]))
# 2025-06-20 13:34:01,026 - root - WARNING - TRAIN DATASET HAS ONLY 532 SAMPLES
# 2025-06-20 13:34:01,516 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:34:04,452 - root - WARNING - Only keeping data for TISSUE Salivarygland
# 2025-06-20 13:34:04,453 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:34:04,573 - root - INFO - Test dataset with 78 samples loaded
# 2025-06-20 13:34:04,580 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:34:04,583 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 20         0              33
#            1              45
# Name: targets, dtype: int64
# 2025-06-20 13:34:04,584 - root - INFO -   Seq len distribution:
# (array([18, 11, 17,  7,  6,  9,  6,  2,  1,  1]), array([ 690. , 1505.6, 2321.2, 3136.8, 3952.4, 4768. , 5583.6, 6399.2,
#        7214.8, 8030.4, 8846. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:34:09,332 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:34:24,196 - root - WARNING - Only keeping data for TISSUE Smallintestine
# 2025-06-20 13:34:24,197 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:34:24,787 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:34:27,994 - root - WARNING - Only keeping data for TISSUE Smallintestine
# 2025-06-20 13:34:27,996 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:34:28,126 - root - INFO - Adding validation dataset with 48 samples to train
# 2025-06-20 13:34:28,127 - root - INFO - Train dataset with 331 samples loaded
# 2025-06-20 13:34:28,129 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:34:28,132 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 21         0              129
#            1              202
# Name: targets, dtype: int64
# 2025-06-20 13:34:28,134 - root - INFO -   Seq len distribution:
# (array([34, 80, 63, 45, 37, 23, 17, 20,  4,  8]), array([ 425. , 1279.7, 2134.4, 2989.1, 3843.8, 4698.5, 5553.2, 6407.9,
#        7262.6, 8117.3, 8972. ]))
# 2025-06-20 13:34:28,135 - root - WARNING - TRAIN DATASET HAS ONLY 331 SAMPLES
# 2025-06-20 13:34:28,432 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:34:31,378 - root - WARNING - Only keeping data for TISSUE Smallintestine
# 2025-06-20 13:34:31,380 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:34:31,501 - root - INFO - Test dataset with 57 samples loaded
# 2025-06-20 13:34:31,508 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:34:31,511 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 21         0              29
#            1              28
# Name: targets, dtype: int64
# 2025-06-20 13:34:31,512 - root - INFO -   Seq len distribution:
# (array([ 7, 10, 11, 11,  6,  5,  1,  2,  1,  3]), array([ 576. , 1302.3, 2028.6, 2754.9, 3481.2, 4207.5, 4933.8, 5660.1,
#        6386.4, 7112.7, 7839. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:34:34,551 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:34:49,328 - root - WARNING - Only keeping data for TISSUE Smoothmuscle
# 2025-06-20 13:34:49,329 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:34:49,908 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:34:53,050 - root - WARNING - Only keeping data for TISSUE Smoothmuscle
# 2025-06-20 13:34:53,052 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:34:53,385 - root - INFO - Adding validation dataset with 88 samples to train
# 2025-06-20 13:34:53,386 - root - INFO - Train dataset with 493 samples loaded
# 2025-06-20 13:34:53,388 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:34:53,391 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 22         0              234
#            1              259
# Name: targets, dtype: int64
# 2025-06-20 13:34:53,393 - root - INFO -   Seq len distribution:
# (array([ 60, 117,  90,  80,  53,  27,  21,  19,  15,  11]), array([ 435. , 1287.9, 2140.8, 2993.7, 3846.6, 4699.5, 5552.4, 6405.3,
#        7258.2, 8111.1, 8964. ]))
# 2025-06-20 13:34:53,394 - root - WARNING - TRAIN DATASET HAS ONLY 493 SAMPLES
# 2025-06-20 13:34:53,818 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:34:56,732 - root - WARNING - Only keeping data for TISSUE Smoothmuscle
# 2025-06-20 13:34:56,734 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:34:56,854 - root - INFO - Test dataset with 95 samples loaded
# 2025-06-20 13:34:56,860 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:34:56,863 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 22         0              35
#            1              60
# Name: targets, dtype: int64
# 2025-06-20 13:34:56,865 - root - INFO -   Seq len distribution:
# (array([ 9, 20, 21, 11, 13,  9,  5,  3,  1,  3]), array([ 407. , 1231.5, 2056. , 2880.5, 3705. , 4529.5, 5354. , 6178.5,
#        7003. , 7827.5, 8652. ]))
# 2025-06-20 13:35:00,932 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:35:15,591 - root - WARNING - Only keeping data for TISSUE Spleen
# 2025-06-20 13:35:15,592 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:35:16,214 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:35:19,408 - root - WARNING - Only keeping data for TISSUE Spleen
# 2025-06-20 13:35:19,410 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:35:19,541 - root - INFO - Adding validation dataset with 69 samples to train
# 2025-06-20 13:35:19,542 - root - INFO - Train dataset with 349 samples loaded
# 2025-06-20 13:35:19,544 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:35:19,546 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 23         0              170
#            1              179
# Name: targets, dtype: int64
# 2025-06-20 13:35:19,548 - root - INFO -   Seq len distribution:
# (array([30, 66, 55, 59, 50, 32, 19, 20,  7, 11]), array([ 408. , 1245.1, 2082.2, 2919.3, 3756.4, 4593.5, 5430.6, 6267.7,
#        7104.8, 7941.9, 8779. ]))
# 2025-06-20 13:35:19,549 - root - WARNING - TRAIN DATASET HAS ONLY 349 SAMPLES
# 2025-06-20 13:35:19,879 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:35:23,022 - root - WARNING - Only keeping data for TISSUE Spleen
# 2025-06-20 13:35:23,024 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:35:23,145 - root - INFO - Test dataset with 65 samples loaded
# 2025-06-20 13:35:23,152 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:35:23,155 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 23         0              37
#            1              28
# Name: targets, dtype: int64
# 2025-06-20 13:35:23,156 - root - INFO -   Seq len distribution:
# (array([ 5,  7, 15, 12,  6,  7,  3,  5,  2,  3]), array([ 461. , 1220.7, 1980.4, 2740.1, 3499.8, 4259.5, 5019.2, 5778.9,
#        6538.6, 7298.3, 8058. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:35:26,294 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:35:40,910 - root - WARNING - Only keeping data for TISSUE Stomach
# 2025-06-20 13:35:40,911 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:35:41,851 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:35:44,658 - root - WARNING - Only keeping data for TISSUE Stomach
# 2025-06-20 13:35:44,660 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:35:44,789 - root - INFO - Adding validation dataset with 64 samples to train
# 2025-06-20 13:35:44,790 - root - INFO - Train dataset with 293 samples loaded
# 2025-06-20 13:35:44,792 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:35:44,794 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 24         0              127
#            1              166
# Name: targets, dtype: int64
# 2025-06-20 13:35:44,796 - root - INFO -   Seq len distribution:
# (array([32, 56, 58, 48, 32, 26, 17,  6,  9,  9]), array([ 375. , 1221.9, 2068.8, 2915.7, 3762.6, 4609.5, 5456.4, 6303.3,
#        7150.2, 7997.1, 8844. ]))
# 2025-06-20 13:35:44,797 - root - WARNING - TRAIN DATASET HAS ONLY 293 SAMPLES
# 2025-06-20 13:35:45,057 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:35:48,139 - root - WARNING - Only keeping data for TISSUE Stomach
# 2025-06-20 13:35:48,141 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:35:48,261 - root - INFO - Test dataset with 55 samples loaded
# 2025-06-20 13:35:48,267 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:35:48,270 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 24         0              21
#            1              34
# Name: targets, dtype: int64
# 2025-06-20 13:35:48,271 - root - INFO -   Seq len distribution:
# (array([ 8, 10, 13,  4,  4,  8,  4,  1,  2,  1]), array([ 565. , 1376.9, 2188.8, 3000.7, 3812.6, 4624.5, 5436.4, 6248.3,
#        7060.2, 7872.1, 8684. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:35:51,138 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:36:05,657 - root - WARNING - Only keeping data for TISSUE Testis
# 2025-06-20 13:36:05,658 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:36:06,240 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:36:09,359 - root - WARNING - Only keeping data for TISSUE Testis
# 2025-06-20 13:36:09,361 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:36:09,498 - root - INFO - Adding validation dataset with 119 samples to train
# 2025-06-20 13:36:09,500 - root - INFO - Train dataset with 715 samples loaded
# 2025-06-20 13:36:09,502 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:36:09,505 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 25         0              259
#            1              456
# Name: targets, dtype: int64
# 2025-06-20 13:36:09,508 - root - INFO -   Seq len distribution:
# (array([111, 161, 121,  96,  90,  56,  24,  23,  25,   8]), array([ 487. , 1333.5, 2180. , 3026.5, 3873. , 4719.5, 5566. , 6412.5,
#        7259. , 8105.5, 8952. ]))
# 2025-06-20 13:36:09,508 - root - WARNING - TRAIN DATASET HAS ONLY 715 SAMPLES
# 2025-06-20 13:36:10,107 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:36:13,175 - root - WARNING - Only keeping data for TISSUE Testis
# 2025-06-20 13:36:13,177 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:36:13,298 - root - INFO - Test dataset with 153 samples loaded
# 2025-06-20 13:36:13,306 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:36:13,309 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 25         0              59
#            1              94
# Name: targets, dtype: int64
# 2025-06-20 13:36:13,310 - root - INFO -   Seq len distribution:
# (array([28, 25, 32, 20, 16, 16,  7,  6,  0,  3]), array([ 513. , 1308.4, 2103.8, 2899.2, 3694.6, 4490. , 5285.4, 6080.8,
#        6876.2, 7671.6, 8467. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:36:19,526 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:36:33,875 - root - WARNING - Only keeping data for TISSUE Thyroid
# 2025-06-20 13:36:33,877 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:36:34,454 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:36:37,618 - root - WARNING - Only keeping data for TISSUE Thyroid
# 2025-06-20 13:36:37,620 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:36:37,757 - root - INFO - Adding validation dataset with 117 samples to train
# 2025-06-20 13:36:37,758 - root - INFO - Train dataset with 636 samples loaded
# 2025-06-20 13:36:37,760 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:36:37,764 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 26         0              211
#            1              425
# Name: targets, dtype: int64
# 2025-06-20 13:36:37,766 - root - INFO -   Seq len distribution:
# (array([ 95, 159, 106,  79,  66,  50,  38,  25,  11,   7]), array([ 401. , 1259.1, 2117.2, 2975.3, 3833.4, 4691.5, 5549.6, 6407.7,
#        7265.8, 8123.9, 8982. ]))
# 2025-06-20 13:36:37,767 - root - WARNING - TRAIN DATASET HAS ONLY 636 SAMPLES
# 2025-06-20 13:36:38,295 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:36:41,208 - root - WARNING - Only keeping data for TISSUE Thyroid
# 2025-06-20 13:36:41,209 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:36:41,525 - root - INFO - Test dataset with 113 samples loaded
# 2025-06-20 13:36:41,534 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:36:41,537 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 26         0              40
#            1              73
# Name: targets, dtype: int64
# 2025-06-20 13:36:41,538 - root - INFO -   Seq len distribution:
# (array([16, 21, 26, 18,  7, 10,  4,  7,  1,  3]), array([ 452. , 1289.9, 2127.8, 2965.7, 3803.6, 4641.5, 5479.4, 6317.3,
#        7155.2, 7993.1, 8831. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:36:47,348 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:37:01,501 - root - WARNING - Only keeping data for TISSUE Tonsil
# 2025-06-20 13:37:01,502 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:37:02,122 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:37:05,292 - root - WARNING - Only keeping data for TISSUE Tonsil
# 2025-06-20 13:37:05,294 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:37:05,432 - root - INFO - Adding validation dataset with 103 samples to train
# 2025-06-20 13:37:05,433 - root - INFO - Train dataset with 540 samples loaded
# 2025-06-20 13:37:05,435 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:37:05,438 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 27         0              272
#            1              268
# Name: targets, dtype: int64
# 2025-06-20 13:37:05,441 - root - INFO -   Seq len distribution:
# (array([ 88, 117,  99,  85,  53,  34,  29,  11,  13,  11]), array([ 503. , 1351.8, 2200.6, 3049.4, 3898.2, 4747. , 5595.8, 6444.6,
#        7293.4, 8142.2, 8991. ]))
# 2025-06-20 13:37:05,441 - root - WARNING - TRAIN DATASET HAS ONLY 540 SAMPLES
# 2025-06-20 13:37:05,948 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:37:08,853 - root - WARNING - Only keeping data for TISSUE Tonsil
# 2025-06-20 13:37:08,855 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:37:08,977 - root - INFO - Test dataset with 93 samples loaded
# 2025-06-20 13:37:08,985 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:37:08,988 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 27         0              43
#            1              50
# Name: targets, dtype: int64
# 2025-06-20 13:37:08,989 - root - INFO -   Seq len distribution:
# (array([13, 23, 12, 17,  9,  6,  3,  6,  3,  1]), array([ 355. , 1187.6, 2020.2, 2852.8, 3685.4, 4518. , 5350.6, 6183.2,
#        7015.8, 7848.4, 8681. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2025-06-20 13:37:13,800 - root - INFO - Loading train data from: train_9.0k_data.pkl
# 2025-06-20 13:37:28,056 - root - WARNING - Only keeping data for TISSUE Urinarybladder
# 2025-06-20 13:37:28,057 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:37:28,635 - root - INFO - Loading val data from: val_9.0k_data.pkl
# 2025-06-20 13:37:31,737 - root - WARNING - Only keeping data for TISSUE Urinarybladder
# 2025-06-20 13:37:31,739 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:37:31,873 - root - INFO - Adding validation dataset with 83 samples to train
# 2025-06-20 13:37:31,875 - root - INFO - Train dataset with 449 samples loaded
# 2025-06-20 13:37:31,876 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:37:31,879 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 28         0              284
#            1              165
# Name: targets, dtype: int64
# 2025-06-20 13:37:31,881 - root - INFO -   Seq len distribution:
# (array([41, 95, 81, 70, 50, 38, 22, 20, 14, 18]), array([ 413. , 1242.1, 2071.2, 2900.3, 3729.4, 4558.5, 5387.6, 6216.7,
#        7045.8, 7874.9, 8704. ]))
# 2025-06-20 13:37:31,882 - root - WARNING - TRAIN DATASET HAS ONLY 449 SAMPLES
# 2025-06-20 13:37:32,290 - root - INFO - Loading test data from: test_9.0k_data.pkl
# 2025-06-20 13:37:35,347 - root - WARNING - Only keeping data for TISSUE Urinarybladder
# 2025-06-20 13:37:35,349 - root - WARNING - Only keeping data for binary CLASSIFICATION
# 2025-06-20 13:37:35,469 - root - INFO - Test dataset with 71 samples loaded
# 2025-06-20 13:37:35,477 - root - INFO - # Stats of dataset after filtering
# 2025-06-20 13:37:35,479 - root - INFO -   Class distribution:
# tissue_id  targets_bin
# 28         0              40
#            1              31
# Name: targets, dtype: int64
# 2025-06-20 13:37:35,481 - root - INFO -   Seq len distribution:
# (array([10, 13, 13,  8,  5, 10,  3,  3,  3,  3]), array([ 463. , 1315.9, 2168.8, 3021.7, 3874.6, 4727.5, 5580.4, 6433.3,
#        7286.2, 8139.1, 8992. ]))
# /export/share/krausef99dm/miniforge3/envs/master-env/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
df_results_rf
# Out:
#             Tissue  Train AUC  Train F1  Train Accuracy  Train Precision  \
# 0          Adrenal        1.0       1.0             1.0              1.0
# 1       Appendices        1.0       1.0             1.0              1.0
# 2            Brain        1.0       1.0             1.0              1.0
# 3            Colon        1.0       1.0             1.0              1.0
# 4         Duodenum        1.0       1.0             1.0              1.0
# 5           Uterus        1.0       1.0             1.0              1.0
# 6        Esophagus        1.0       1.0             1.0              1.0
# 7    Fallopiantube        1.0       1.0             1.0              1.0
# 8              Fat        1.0       1.0             1.0              1.0
# 9      Gallbladder        1.0       1.0             1.0              1.0
# 10           Heart        1.0       1.0             1.0              1.0
# 11          Kidney        1.0       1.0             1.0              1.0
# 12           Liver        1.0       1.0             1.0              1.0
# 13            Lung        1.0       1.0             1.0              1.0
# 14       Lymphnode        1.0       1.0             1.0              1.0
# 15           Ovary        1.0       1.0             1.0              1.0
# 16        Pancreas        1.0       1.0             1.0              1.0
# 17        Placenta        1.0       1.0             1.0              1.0
# 18        Prostate        1.0       1.0             1.0              1.0
# 19          Rectum        1.0       1.0             1.0              1.0
# 20   Salivarygland        1.0       1.0             1.0              1.0
# 21  Smallintestine        1.0       1.0             1.0              1.0
# 22    Smoothmuscle        1.0       1.0             1.0              1.0
# 23          Spleen        1.0       1.0             1.0              1.0
# 24         Stomach        1.0       1.0             1.0              1.0
# 25          Testis        1.0       1.0             1.0              1.0
# 26         Thyroid        1.0       1.0             1.0              1.0
# 27          Tonsil        1.0       1.0             1.0              1.0
# 28  Urinarybladder        1.0       1.0             1.0              1.0
#
#     Train Recall  Test AUC   Test F1  Test Accuracy  Test Precision  \
# 0            1.0  0.462862  0.590164       0.468085        0.473684
# 1            1.0  0.567808  0.045455       0.681818        1.000000
# 2            1.0  0.543047  0.808081       0.680672        0.683761
# 3            1.0  0.789911  0.704225       0.752941        0.833333
# 4            1.0  0.565882  0.372093       0.542373        0.444444
# 5            1.0  0.581178  0.724638       0.641509        0.625000
# 6            1.0  0.477583  0.093023       0.566667        0.166667
# 7            1.0  0.627539  0.769231       0.662921        0.735294
# 8            1.0  0.573465  0.093023       0.732877        0.400000
# 9            1.0  0.608182  0.434783       0.623188        0.476190
# 10           1.0  0.528186  0.294118       0.609756        0.588235
# 11           1.0  0.798021  0.704000       0.710938        0.698413
# 12           1.0  0.555288  0.366197       0.618644        0.419355
# 13           1.0  0.703089  0.810345       0.721519        0.728682
# 14           1.0  0.556571  0.606061       0.566667        0.645161
# 15           1.0  0.471522  0.487805       0.519084        0.545455
# 16           1.0  0.648323  0.519685       0.636905        0.589286
# 17           1.0  0.473077  0.615385       0.512195        0.615385
# 18           1.0  0.750158  0.695652       0.743902        0.631579
# 19           1.0  0.653103  0.655738       0.611111        0.625000
# 20           1.0  0.655892  0.643678       0.602564        0.666667
# 21           1.0  0.683498  0.714286       0.649123        0.595238
# 22           1.0  0.653333  0.684211       0.621053        0.722222
# 23           1.0  0.616313  0.557377       0.584615        0.515152
# 24           1.0  0.460784  0.684211       0.563636        0.619048
# 25           1.0  0.499820  0.716157       0.575163        0.607407
# 26           1.0  0.759418  0.775758       0.672566        0.695652
# 27           1.0  0.711628  0.659574       0.655914        0.704545
# 28           1.0  0.594355  0.325581       0.591549        0.583333
#
#     Test Recall  Train Time (s)
# 0      0.782609        0.304210
# 1      0.023256        0.552087
# 2      0.987654        0.737857
# 3      0.609756        0.386968
# 4      0.320000        0.306681
# 5      0.862069        0.260196
# 6      0.064516        0.397382
# 7      0.806452        0.353287
# 8      0.052632        0.711632
# 9      0.400000        0.311719
# 10     0.196078        0.583460
# 11     0.709677        0.511920
# 12     0.325000        0.468091
# 13     0.912621        0.796191
# 14     0.571429        0.368484
# 15     0.441176        0.649425
# 16     0.464789        0.724094
# 17     0.615385        0.393347
# 18     0.774194        0.365155
# 19     0.689655        0.281715
# 20     0.622222        0.408998
# 21     0.892857        0.297777
# 22     0.650000        0.394091
# 23     0.607143        0.304556
# 24     0.764706        0.282581
# 25     0.872340        0.589279
# 26     0.876712        0.482355
# 27     0.620000        0.400027
# 28     0.225806        0.367381

# %%
df_results_mlp
# Out:
#             Tissue  Train AUC  Train F1  Train Accuracy  Train Precision  \
# 0          Adrenal   0.788220  0.763819        0.715152         0.713615
# 1       Appendices   0.712819  0.264706        0.717115         0.654545
# 2            Brain   0.704905  0.841148        0.736964         0.742892
# 3            Colon   0.832051  0.712531        0.753684         0.783784
# 4         Duodenum   0.757527  0.654321        0.686275         0.679487
# 5           Uterus   0.812236  0.812680        0.758364         0.746032
# 6        Esophagus   0.760746  0.513889        0.718876         0.698113
# 7    Fallopiantube   0.785680  0.794224        0.734884         0.745763
# 8              Fat   0.731447  0.214286        0.748731         0.692308
# 9      Gallbladder   0.774634  0.635379        0.715493         0.692913
# 10           Heart   0.754429  0.585635        0.699599         0.638554
# 11          Kidney   0.837307  0.740741        0.752212         0.813559
# 12           Liver   0.606397  0.024291        0.599668         1.000000
# 13            Lung   0.764180  0.801157        0.719388         0.734748
# 14       Lymphnode   0.667451  0.689655        0.527446         0.526316
# 15           Ovary   0.559861  0.000000        0.537983         0.000000
# 16        Pancreas   0.756057  0.607735        0.710794         0.685358
# 17        Placenta   0.753888  0.704062        0.673077         0.684211
# 18        Prostate   0.825691  0.756871        0.753747         0.718876
# 19          Rectum   0.867927  0.830097        0.794118         0.810427
# 20   Salivarygland   0.820412  0.734082        0.733083         0.705036
# 21  Smallintestine   0.827654  0.809412        0.755287         0.771300
# 22    Smoothmuscle   0.760189  0.685714        0.687627         0.727273
# 23          Spleen   0.770227  0.712401        0.687679         0.675000
# 24         Stomach   0.811356  0.781421        0.726962         0.715000
# 25          Testis   0.729781  0.789575        0.695105         0.705172
# 26         Thyroid   0.795606  0.828947        0.754717         0.776181
# 27          Tonsil   0.798645  0.684426        0.714815         0.759091
# 28  Urinarybladder   0.750576  0.496000        0.719376         0.729412
#
#     Train Recall  Test AUC   Test F1  Test Accuracy  Test Precision  \
# 0       0.821622  0.539855  0.618182       0.553191        0.531250
# 1       0.165899  0.559185  0.000000       0.651515        0.000000
# 2       0.969355  0.670240  0.806283       0.689076        0.700000
# 3       0.653153  0.746674  0.650000       0.670588        0.666667
# 4       0.630952  0.509412  0.382979       0.508475        0.409091
# 5       0.892405  0.568966  0.666667       0.584906        0.594595
# 6       0.406593  0.435210  0.208333       0.577778        0.294118
# 7       0.849421  0.646356  0.745763       0.662921        0.785714
# 8       0.126761  0.527290  0.046512       0.719178        0.200000
# 9       0.586667  0.505455  0.423077       0.565217        0.407407
# 10      0.540816  0.516068  0.400000       0.560976        0.461538
# 11      0.679887  0.800098  0.695652       0.726562        0.754717
# 12      0.012295  0.553846  0.000000       0.644068        0.000000
# 13      0.880763  0.750397  0.807018       0.721519        0.736000
# 14      1.000000  0.488000  0.736842       0.583333        0.583333
# 15      0.000000  0.423436  0.000000       0.480916        0.000000
# 16      0.545906  0.668506  0.535433       0.648810        0.607143
# 17      0.725100  0.585256  0.693069       0.621951        0.714286
# 18      0.799107  0.725490  0.619718       0.670732        0.550000
# 19      0.850746  0.646897  0.666667       0.611111        0.617647
# 20      0.765625  0.691582  0.650602       0.628205        0.710526
# 21      0.851485  0.612069  0.657143       0.578947        0.547619
# 22      0.648649  0.541905  0.538462       0.494737        0.636364
# 23      0.754190  0.657336  0.516129       0.538462        0.470588
# 24      0.861446  0.390756  0.602740       0.472727        0.564103
# 25      0.896930  0.493329  0.728070       0.594771        0.619403
# 26      0.889412  0.739041  0.763158       0.681416        0.734177
# 27      0.623134  0.720930  0.615385       0.623656        0.682927
# 28      0.375758  0.489516  0.297872       0.535211        0.437500
#
#     Test Recall  Train Time (s)
# 0      0.739130        2.699573
# 1      0.000000        4.276603
# 2      0.950617        5.518711
# 3      0.634146        3.881353
# 4      0.360000        2.756858
# 5      0.758621        2.361644
# 6      0.161290        3.956932
# 7      0.709677        3.339609
# 8      0.026316        5.921046
# 9      0.440000        2.752788
# 10     0.352941        5.718536
# 11     0.645161        4.892248
# 12     0.000000        0.758423
# 13     0.893204        7.240052
# 14     1.000000        0.186275
# 15     0.000000        0.340763
# 16     0.478873        5.831069
# 17     0.673077        3.771473
# 18     0.709677        3.829891
# 19     0.724138        2.706834
# 20     0.600000        4.223098
# 21     0.821429        2.649409
# 22     0.466667        3.542554
# 23     0.571429        2.728301
# 24     0.647059        2.491165
# 25     0.882979        5.449074
# 26     0.794521        5.179472
# 27     0.560000        4.234559
# 28     0.225806        3.720298

# %%
df_results_rf["Test AUC"].mean()
# Out:
# 0.605856476720072

# %%
df_results_mlp["Test AUC"].mean()
# Out:
# 0.5932103863181245

# %%
df_results.to_csv("visualisation/data/rfc_per_tissue_scores.csv")
