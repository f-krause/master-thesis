# %%
# PTRnet Ablation Study Results

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm

import vis_utils
from visualisation.custom_colors import blue_shades

font_path = r'C:\Users\Felix\AppData\Local\Microsoft\Windows\Fonts\SourceSansPro-Regular.ttf'
fm.fontManager.addfont(font_path)
source_sans_pro = fm.FontProperties(fname=font_path)

plt.rcParams['font.family'] = source_sans_pro.get_name()

# %%
STORE = True
# STORE = False

# %%
# Load datafile
df_raw = pd.read_csv("data/runs-12_34_50-10-Jun-25-PTRnet-final.csv")
df_raw.loc[:, "pretrain"] = df_raw.experiment.str.contains("pretrain")
df_raw = df_raw[df_raw.pretrain == False]
df_raw.loc[:, "run_id_temp"] = df_raw.experiment.str.split("/").str[2]
df_raw.loc[:, "run_id"] = df_raw.run_id_temp.str.split("_").str[0]

# %%
df_raw
# Out:
#                              run                    experiment     AUC_val  \
# 0  Run: 0163aaa98f844cbab63d7434  binary/ptrnet/31_ptrnet_freq  0.68598397
# 2  Run: 8d0b651a26384dd9baf90115  binary/ptrnet/30_ptrnet_freq  0.68392869
# 3  Run: 36e27b83c3db4e4e9d58f5b3  binary/ptrnet/29_ptrnet_freq  0.68674553
# 4  Run: 2c0dbcfb19fa418bbb2240dc  binary/ptrnet/28_ptrnet_freq  0.67996119
# 5  Run: e940d23f7477445c85c54b2e  binary/ptrnet/27_ptrnet_freq  0.67980306
# 6  Run: 76de08b7ba6e4a5880844a80       binary/ptrnet/44_ptrnet  0.68407747
# 7  Run: 5fbdb940ed7646a7b8f5b7f4  binary/ptrnet/26_ptrnet_freq  0.68499404
#
#     AUC_train  nr_params  avg_epoch_time     nr_flops  training_time_min  \
# 0  0.71945254     272033        0.404033  13556666368            13.3331
# 2  0.72148586     272033        0.405883  13556666368            21.9177
# 3  0.71558985     611905        0.460457  53644118016            21.6415
# 4  0.70356534     508399        0.784276  39687928320            13.3327
# ...

# %%
# Assign runnames to ids
run_names = {
    26: "baseline (tuned PTRnet)",
    44: "- codon frequencies",
    27: "- AUG alignment",
    28: "OHE of inputs",
    29: "concat tissue embeddings",
    30: "sequence only",
    31: "+ pretraining",
}

df_raw["run_id"] = df_raw["run_id"].astype(int)
df_raw.loc[:, "name"] = df_raw.run_id.map(run_names)

# %%
df = df_raw[["run", "run_id", "name", "AUC_train", "AUC_val", "F1_val", "Precision_val", "Recall_val", "Accuracy_val"]].copy()

# %%
# rename columns from _val to _test
df.rename(columns={
    "AUC_val": "AUC_test",
    "F1_val": "F1_test",
    "Precision_val": "Precision_test",
    "Recall_val": "Recall_test",
    "Accuracy_val": "Accuracy_test"
}, inplace=True)

# %%
# convert to float
cols_to_convert = [col for col in df.columns if col not in ['run', "run_id", "name"]]
df.loc[:, cols_to_convert] = df[cols_to_convert].astype(float)

# %%
df.sort_values(by="AUC_test", ascending=True, inplace=True)
df
# Out:
#                              run  run_id                      name AUC_train  \
# 5  Run: e940d23f7477445c85c54b2e      27           - AUG alignment  0.754272
# 4  Run: 2c0dbcfb19fa418bbb2240dc      28             OHE of inputs  0.703565
# 2  Run: 8d0b651a26384dd9baf90115      30             sequence only  0.721486
# 6  Run: 76de08b7ba6e4a5880844a80      44       - codon frequencies  0.713702
# 7  Run: 5fbdb940ed7646a7b8f5b7f4      26   baseline (tuned PTRnet)  0.721312
# 0  Run: 0163aaa98f844cbab63d7434      31             + pretraining  0.719453
# 3  Run: 36e27b83c3db4e4e9d58f5b3      29  concat tissue embeddings   0.71559
#
#    AUC_test   F1_test Precision_test Recall_test Accuracy_test
# 5  0.679803   0.62876       0.638124    0.619667      0.635052
# 4  0.679961   0.62403       0.638427    0.610268      0.633249
# 2  0.683929    0.6181       0.642969    0.595083      0.633249
# 6  0.684077  0.634864       0.629893    0.639913      0.632889
# ...

# %%
# Adding confidence intervals for test AUC

from confidenceinterval import roc_auc_score

test_aucs = []
test_ci_lower_bounds = []
test_ci_upper_bounds = []
train_aucs = []
train_ci_lower_bounds = []
train_ci_upper_bounds = []
for run_id in df.run_id:
    # Validation value
    predictions_df = pd.read_csv(f"data/predictions/ptrnet/{run_id}/predictions_val_fold-0.csv")
    test_y_true = predictions_df.target.to_numpy()
    test_y_pred = predictions_df.prediction.to_numpy()
    test_auc, test_ci = roc_auc_score(test_y_true, test_y_pred, confidence_level=0.95, method='delong')
    # test_auc, test_ci = roc_auc_score(test_y_true, test_y_pred, confidence_level=0.95, method='bootstrap_bca', n_resamples=1500)
    # print(f"AUC: {auc}, 95% CI: {ci}")

    test_aucs.append(test_auc)
    test_ci_lower_bounds.append(test_ci[0].item())
    test_ci_upper_bounds.append(test_ci[1].item())

    # Training value
    predictions_df = pd.read_csv(f"data/predictions/ptrnet/{run_id}/predictions_train_fold-0.csv")
    train_y_true = predictions_df.target.to_numpy()
    train_y_pred = predictions_df.prediction.to_numpy()
    auc, ci = roc_auc_score(train_y_true, train_y_pred, confidence_level=0.95, method='delong')

    train_aucs.append(auc)
    train_ci_lower_bounds.append(ci[0].item())
    train_ci_upper_bounds.append(ci[1].item())


df.loc[:, "test_auc_ci_lower"] = test_ci_lower_bounds
df.loc[:, "test_auc_ci_upper"] = test_ci_upper_bounds
df.loc[:, "train_auc_ci_lower"] = train_ci_lower_bounds
df.loc[:, "train_auc_ci_upper"] = train_ci_upper_bounds

# %%
fig, ax = plt.subplots(figsize=(7.5, 4))
bar_height = 0.35
y = range(len(df))

test_xerrs = [df["AUC_test"] - df["test_auc_ci_lower"], df["test_auc_ci_upper"] - df["AUC_test"]]
train_xerrs = [df["AUC_train"] - df["train_auc_ci_lower"], df["train_auc_ci_upper"] - df["AUC_train"]]

# Bars with spacing
ax.barh([i + bar_height / 2 for i in y], df["AUC_test"], height=bar_height, xerr=test_xerrs, label='Test', color=blue_shades[2], error_kw={'elinewidth': 1.5, 'ecolor':"#555555", 'capsize': 1.5})
ax.barh([i - bar_height / 2 for i in y], df["AUC_train"], height=bar_height, xerr=train_xerrs, label='Train', color=blue_shades[0], error_kw={'elinewidth': 1.5, 'ecolor':"#555555", 'capsize': 1.5})

# Labels and legend
ax.set_yticks(y)
ax.set_yticklabels(df.name)
ax.set_xlabel("AUC")
ax.set_title("PTRnet Ablation Study Results")
ax.legend()
# ax.set_xlim(0.5, max(df["AUC_test"].max(), df["AUC_train"].max()) * 1.035)
ax.set_xlim(min(df["AUC_test"].min(), df["AUC_train"].min()) * 0.95, max(df["AUC_test"].max(), df["AUC_train"].max()) * 1.02)
# add a vertical grey line at the baseline AUC value
baseline_auc = df[df.run_id == 26]["AUC_test"].values[0]
ax.axvline(baseline_auc, color="grey", linestyle="--", label="Baseline AUC", lw=1)
plt.tight_layout()

if STORE:
    plt.savefig(os.getenv("OUTPUT_DIR") + f"/ptrnet_ablation_barplot.pdf", format="pdf", bbox_inches="tight")

plt.show()

# %%
# Python
fig, ax = plt.subplots(figsize=(7.5, 4))
y = range(len(df))
dot_offset = 0.17

test_xerrs = [df["AUC_test"] - df["test_auc_ci_lower"], df["test_auc_ci_upper"] - df["AUC_test"]]
train_xerrs = [df["AUC_train"] - df["train_auc_ci_lower"], df["train_auc_ci_upper"] - df["AUC_train"]]

# Test AUC dots with error bars
ax.errorbar(
    df["AUC_test"],
    [i + dot_offset for i in y],
    xerr=test_xerrs,
    fmt='o',
    color=blue_shades[3],
    label='Test',
    ecolor="#888888",
    elinewidth=1.5,
    capsize=3,
    markersize=6
)

# Train AUC dots with error bars
ax.errorbar(
    df["AUC_train"],
    [i - dot_offset for i in y],
    xerr=train_xerrs,
    fmt='o',
    color=blue_shades[1],
    label='Train',
    ecolor="#888888",
    elinewidth=1.5,
    capsize=3,
    markersize=6
)

# Labels and legend
ax.set_yticks(y)
ax.set_yticklabels(df.name)
ax.set_xlabel("AUC")
ax.set_title("PTRnet Ablation Study Results")
ax.legend()
ax.set_xlim(min(df["AUC_test"].min(), df["AUC_train"].min()) * 0.95, max(df["AUC_test"].max(), df["AUC_train"].max()) * 1.02)
baseline_auc = df[df.run_id == 26]["AUC_test"].values[0]
ax.axvline(baseline_auc, color="grey", linestyle="--", label="Baseline AUC", lw=1)
plt.tight_layout()

if STORE:
    plt.savefig(os.getenv("OUTPUT_DIR") + f"/ptrnet_ablation_dotplot.pdf", format="pdf", bbox_inches="tight")

plt.show()

# %% [markdown]
# ## All metrics table

# %%
# See benchmark_test_results.ipynb
